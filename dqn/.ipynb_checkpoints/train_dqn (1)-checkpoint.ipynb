# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
# FOLDER_PATH = '/home/taindp/Jupyter/custom_dqn'
FOLDER_PATH = '/content/drive/MyDrive/Colab Notebooks/go-orient'
# FOLDER_PATH  = '/home/taindp/Jupyter/reference/dqn_ref'
sys.path.append(FOLDER_PATH)

# %%
import tensorflow as tf
tf.compat.v1.disable_eager_execution()
print(tf.compat.v1.get_default_graph())
# Out:
# <tensorflow.python.framework.ops.Graph object at 0x7f664a43a470>

# %%
# sys.path

# %%
# %load_ext autoreload
# %autoreload 2
from user_simulator import UserSimulator
from error_model_controller import ErrorModelController
from dqn_agent import DQNAgent
# from dqn_agent import get_action
from state_tracker import StateTracker
import pickle, argparse, json, math
from utils import remove_empty_slots
from user import User
import time
import json
from tqdm import tqdm
# %cd $FOLDER_PATH
# from tqdm import tqdm
# Out:
# /content/drive/MyDrive/Colab Notebooks/go-orient

# %%
def run_round(state, warmup=False):
#     print('State of run_round',state)
#     state : array 12*14
    # 1) Agent takes action given state tracker's representation of dialogue (state)
    agent_action_index, agent_action = dqn_agent.get_action(state, use_rule=warmup)
    # print('agent_action_index',agent_action_index)
    # print('agent_action',agent_action)
    # 2) Update state tracker with the agent's action
    state_tracker.update_state_agent(agent_action)
    # print('agent_action_update',agent_action)
    # 3) User takes action given agent action
    user_action, reward, done, success = user.step(agent_action)
    # print('user_action',user_action)
    # print('reward',reward)
    # print('done',done)
    # print('success',success)
    if not done:
        # 4) Infuse error into semantic frame level of user action
        emc.infuse_error(user_action)
    # 5) Update state tracker with user action
    state_tracker.update_state_user(user_action)
    # print('update_state_user',user_action)
    # 6) Get next state and add experience
    next_state = state_tracker.get_state(done)
    dqn_agent.add_experience(state, agent_action_index, reward, next_state, done)
    return next_state, reward, done, success


def warmup_run():
    """
    Runs the warmup stage of training which is used to fill the agents memory.

    The agent uses it's rule-based policy to make actions. The agent's memory is filled as this runs.
    Loop terminates when the size of the memory is equal to WARMUP_MEM or when the memory buffer is full.

    """

    print('Warmup Started...')
    total_step = 0
    
    with tqdm(total=WARMUP_MEM) as pbar:
#         total_step = 0 
        while total_step != WARMUP_MEM and not dqn_agent.is_memory_full():
#             counter += 1
            # Reset episode
            episode_reset()
            done = False
            # Get initial state from state tracker
            state = state_tracker.get_state()
            # print('State warmup', state)
            # print('Type state',type(state))
            while not done:
                next_state, _, done, _ = run_round(state, warmup=True)
                total_step += 1
                state = next_state
            # print(total_step)
            # time.sleep(1)
#             pbar.update(1)
    print('...Warmup Ended')


def train_run():
    """
    Runs the loop that trains the agent.

    Trains the agent on the goal-oriented chatbot task. Training of the agent's neural network occurs every episode that
    TRAIN_FREQ is a multiple of. Terminates when the episode reaches NUM_EP_TRAIN.

    """

    print('Training Started...')
    episode = 0
    period_reward_total = 0
    period_success_total = 0
    success_rate_best = 0.76
    while episode < NUM_EP_TRAIN:
        episode_reset()
        episode += 1
        print('Current episode:',episode)
        done = False
        state = state_tracker.get_state()
        # print('Current state',state)
        while not done:
            next_state, reward, done, success = run_round(state)
            # print('Next state',next_state)
            # print('Reward', reward)
            # print('Done',done)
            period_reward_total += reward
            state = next_state
        print("success :{0}".format(success))

        period_success_total += success
        print('period_success_total',period_success_total)
        # Train
        if episode % TRAIN_FREQ == 0:
            # Check success rate
            success_rate = period_success_total / TRAIN_FREQ
            avg_reward = period_reward_total / TRAIN_FREQ
            print("episode {0}: success rate: {1}".format(episode, success_rate))

            # Flush
            if success_rate >= success_rate_best and success_rate >= SUCCESS_RATE_THRESHOLD:
                dqn_agent.empty_memory()
            # Update current best success rate
            if success_rate > success_rate_best:
                print('Episode: {} NEW BEST SUCCESS RATE: {} Avg Reward: {}' .format(episode, success_rate, avg_reward))
                success_rate_best = success_rate
                dqn_agent.save_weights()
            period_success_total = 0
            period_reward_total = 0
            # Copy
            dqn_agent.copy()
            # Train
            dqn_agent.train()
    print('...Training Ended')


def episode_reset():
    """
    Resets the episode/conversation in the warmup and training loops.

    Called in warmup and train to reset the state tracker, user and agent. Also get's the initial user action.

    """

    # First reset the state tracker
    state_tracker.reset()
    # Then pick an init user action
    user_action = user.reset()
    # Infuse with error
    emc.infuse_error(user_action)
    # And update state tracker
    state_tracker.update_state_user(user_action)
    # Finally, reset agent
    dqn_agent.reset()

# %%
CONSTANTS_FILE_PATH = f'{FOLDER_PATH}/constants.json'
constants_file = CONSTANTS_FILE_PATH

with open(constants_file) as f:
    constants = json.load(f)

# %%
constants
# Out:
# {'agent': {'batch_size': 16,
#   'dqn_hidden_size': 80,
#   'epsilon_init': 0.0,
#   'gamma': 0.9,
#   'learning_rate': 0.001,
#   'load_weights_file_path': '',
#   'max_mem_size': 500000,
#   'save_weights_file_path': '',
#   'vanilla': True},
#  'db_file_paths': {'database': 'data/movie_db.pkl',
#   'dict': 'data/movie_dict.pkl',
#   'user_goals': 'data/movie_user_goals.pkl'},
#  'emc': {'intent_error_prob': 0.0,
#   'slot_error_mode': 0,
#   'slot_error_prob': 0.05},
#  'run': {'max_round_num': 20,
#   'num_ep_run': 40000,
#   'success_rate_threshold': 0.3,
#   'train_freq': 100,
#   'usersim': True,
#   'warmup_mem': 1000}}

# %%
# Load file path constants
file_path_dict = constants['db_file_paths']
DATABASE_FILE_PATH = file_path_dict['database']
DICT_FILE_PATH = file_path_dict['dict']
USER_GOALS_FILE_PATH = file_path_dict['user_goals']

# %%
run_dict = constants['run']
USE_USERSIM = run_dict['usersim']
WARMUP_MEM = run_dict['warmup_mem']
NUM_EP_TRAIN = run_dict['num_ep_run']
TRAIN_FREQ = run_dict['train_freq']
MAX_ROUND_NUM = run_dict['max_round_num']
SUCCESS_RATE_THRESHOLD = run_dict['success_rate_threshold']

# %%
# database= json.load(open(DATABASE_FILE_PATH,encoding='utf-8'))
database = pickle.load(open(DATABASE_FILE_PATH, 'rb'), encoding='latin1')
remove_empty_slots(database)

# %%
type(database)
# Out:
# dict

# %%
database

# %%
# db_dict = json.load(open(DICT_FILE_PATH,encoding='utf-8'))[0]
db_dict = pickle.load(open(DICT_FILE_PATH, 'rb'), encoding='latin1')

# %%
db_dict

# %%
# user_goals = json.load(open(USER_GOALS_FILE_PATH,encoding='utf-8'))
user_goals = pickle.load(open(USER_GOALS_FILE_PATH, 'rb'), encoding='latin1')

# %%
user_goals
# Out:
# [{'diaact': 'request',
#   'inform_slots': {'city': 'birmingham',
#    'date': 'today',
#    'moviename': 'zootopia',
#    'numberofpeople': '1',
#    'starttime': 'around 2pm',
#    'state': 'al',
#    'theater': 'carmike summit 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'deadpool',
#    'numberofpeople': '2',
#    'starttime': '9:00 pm',
#    'theater': 'amc pacific place 11 theater'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'birmingham',
#    'date': 'today',
#    'moviename': 'deadpool',
#    'numberofpeople': '4',
#    'starttime': 'around 6pm',
#    'state': 'al',
#    'theater': 'carmike summit 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'zootopia',
#    'numberofpeople': '2',
#    'starttime': '9:10 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'hail caesar',
#    'numberofpeople': '2',
#    'starttime': '8:45 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'portland',
#    'moviename': 'star wars',
#    'numberofpeople': '5',
#    'state': 'oregon'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'room',
#    'numberofpeople': '2',
#    'starttime': '9:30 pm',
#    'theater': 'amc pacific place 11 theater'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'the witch',
#    'numberofpeople': '2',
#    'starttime': '9:30 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'the witch',
#    'numberofpeople': '2',
#    'starttime': '9:30 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'triple 9',
#    'numberofpeople': '6',
#    'starttime': '7:10 pm',
#    'theater': 'amc lowes oak tree'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'zootopia',
#    'numberofpeople': '2',
#    'starttime': '9:10 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'birmingham',
#    'date': 'today',
#    'moviename': 'deadpool',
#    'numberofpeople': '2',
#    'starttime': '4 pm',
#    'state': 'al'},
#   'request_slots': {'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'the big short',
#    'numberofpeople': '2',
#    'starttime': '8:45 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'the big short',
#    'numberofpeople': '2',
#    'starttime': '8:45 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'zootopia',
#    'numberofpeople': '2',
#    'starttime': '9:10 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'stony brook',
#    'moviename': ' Young Messiah',
#    'numberofpeople': '1',
#    'starttime': ' Matinee',
#    'state': 'ny'},
#   'request_slots': {'date': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'Petaluma',
#    'moviename': 'eddie the eagle',
#    'numberofpeople': '4'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'date': 'tomorrow',
#    'moviename': 'risen',
#    'numberofpeople': '3',
#    'theater': 'regency commerce 14'},
#   'request_slots': {'starttime': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'zoolander 2',
#    'numberofpeople': '2',
#    'starttime': '9:25 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'deadpool',
#    'numberofpeople': '2',
#    'starttime': '9:00 pm',
#    'theater': 'amc pacific place 11 theater'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'date': 'saturday',
#    'moviename': 'zootopia',
#    'numberofpeople': '1',
#    'starttime': 'around 2pm'},
#   'request_slots': {'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'the witch',
#    'numberofpeople': '2',
#    'starttime': '9:30 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'moviename': 'zootopia', 'numberofpeople': '4'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'moviename': 'Avengers', 'numberofpeople': '4'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'distanceconstraints': 'close to 95833',
#    'moviename': 'zoology',
#    'numberofpeople': '3'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'race',
#    'numberofpeople': '2',
#    'starttime': '4:50 pm',
#    'theater': 'amc lowes oak tree 6'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'moviename': 'deadpool', 'numberofpeople': '3'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'hail caesar',
#    'numberofpeople': '2',
#    'starttime': '7:15 pm',
#    'theater': 'amc lowes oak tree 6'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'birmingham',
#    'date': 'today',
#    'moviename': 'zootopia',
#    'numberofpeople': '2',
#    'starttime': 'around 4pm',
#    'state': 'al'},
#   'request_slots': {'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'date': 'tomorrow',
#    'moviename': 'zootopia',
#    'numberofpeople': '5',
#    'starttime': 'night'},
#   'request_slots': {'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'zoolander 2',
#    'numberofpeople': '2',
#    'starttime': '9:25 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'date': 'tonight',
#    'moviename': 'zootopia',
#    'numberofpeople': '1'},
#   'request_slots': {'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'birmingham',
#    'date': 'saturday',
#    'moviename': 'deadpool',
#    'numberofpeople': '3',
#    'starttime': '2pm',
#    'state': 'al',
#    'theater': 'carmike summit 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'sacramento',
#    'date': 'tomorrow',
#    'moviename': 'gods of egypt',
#    'numberofpeople': '4',
#    'theater': 'regal theater'},
#   'request_slots': {'starttime': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'date': 'tomorrow',
#    'moviename': '10 cloverfield lane',
#    'numberofpeople': '3'},
#   'request_slots': {'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'moviename': 'zootopia', 'numberofpeople': '2'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'zoolander 2',
#    'numberofpeople': '2',
#    'starttime': '9:25 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'date': 'tomorrow',
#    'moviename': 'risen',
#    'numberofpeople': '2',
#    'theater': 'regency commerce 14'},
#   'request_slots': {'starttime': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'date': 'this friday',
#    'moviename': 'star wars',
#    'numberofpeople': '4'},
#   'request_slots': {'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'portland',
#    'moviename': 'zootopia',
#    'numberofpeople': '3',
#    'state': 'oregon'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'date': 'tonight',
#    'moviename': 'zootopia',
#    'numberofpeople': '5'},
#   'request_slots': {'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'portland',
#    'moviename': 'star wars',
#    'numberofpeople': '5',
#    'state': 'oregon'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'zootopia',
#    'numberofpeople': '2',
#    'starttime': '9:10 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'date': 'tonight',
#    'moviename': 'zootopia',
#    'numberofpeople': '1'},
#   'request_slots': {'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'hail caesar',
#    'numberofpeople': '2',
#    'starttime': '8:45 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'distanceconstraints': 'near me',
#    'moviename': 'kung fu panda 3',
#    'numberofpeople': '4'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'hail caesar',
#    'numberofpeople': '2',
#    'starttime': '8:45 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'moviename': 'london has fallen',
#    'numberofpeople': 'two',
#    'zip': '90602'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'zootopia',
#    'numberofpeople': '2',
#    'starttime': '9:10 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow night',
#    'moviename': 'zootopia',
#    'numberofpeople': 'one'},
#   'request_slots': {'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'moviename': 'first', 'numberofpeople': '2'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'date': 'saturday',
#    'moviename': 'zootopia',
#    'numberofpeople': '4',
#    'starttime': 'around 2pm'},
#   'request_slots': {'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'date': 'tonight',
#    'moviename': 'zootopia',
#    'numberofpeople': '3'},
#   'request_slots': {'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'moviename': 'whiskey tango foxtrot',
#    'numberofpeople': '3'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'date': 'tomorrow night',
#    'moviename': 'zootopia',
#    'numberofpeople': '5'},
#   'request_slots': {'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'distanceconstraints': 'near me',
#    'moviename': 'kung fu panda 3',
#    'numberofpeople': '1'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'moviename': 'london has fallen', 'numberofpeople': '5'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'portland',
#    'moviename': 'whiskey tango foxtrot',
#    'numberofpeople': '4',
#    'state': 'oregon'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'moviename': 'deadpool', 'numberofpeople': '5'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'risen',
#    'numberofpeople': '2',
#    'starttime': '4:25 pm',
#    'theater': 'amc lowes oak tree 6'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'room',
#    'numberofpeople': '2',
#    'starttime': '9:30 pm',
#    'theater': 'pacific place 11 theater',
#    'theater_chain': 'amc'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'moviename': 'deadpool',
#    'numberofpeople': '2'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'los angeles',
#    'date': 'tomorrow',
#    'moviename': 'deadpool',
#    'numberofpeople': '4',
#    'starttime': '8pm'},
#   'request_slots': {'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'date': 'this weekend',
#    'moviename': 'batman moviename',
#    'numberofpeople': '1'},
#   'request_slots': {'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'distanceconstraints': 'near me',
#    'moviename': 'zootopia',
#    'numberofpeople': '5'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'detroit',
#    'date': 'tomorrow',
#    'moviename': 'deadpool',
#    'numberofpeople': '3',
#    'starttime': '7pm'},
#   'request_slots': {'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'regency',
#    'date': 'tomorrow',
#    'moviename': 'creed',
#    'numberofpeople': 'four',
#    'starttime': 'around noon'},
#   'request_slots': {'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'los angeles',
#    'date': 'tomorrow',
#    'moviename': 'zootopia',
#    'numberofpeople': '5',
#    'starttime': '8pm'},
#   'request_slots': {'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'risen',
#    'numberofpeople': '2',
#    'starttime': '4:25 pm',
#    'theater': 'amc lowes oak tree 6'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'room',
#    'numberofpeople': '2',
#    'starttime': '9:30 pm',
#    'theater': 'amc pacific place 11 theater'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'birmingham',
#    'date': 'today',
#    'moviename': 'london had fallen',
#    'numberofpeople': '2',
#    'starttime': 'around 2pm',
#    'state': 'al',
#    'theater': 'carmike summit 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'room',
#    'numberofpeople': '2',
#    'starttime': '4:50 pm',
#    'theater': 'amc lowes oak tree 6'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'philadelphia',
#    'date': 'tomorrow',
#    'moviename': 'deadpool',
#    'numberofpeople': '3',
#    'zip': '19101'},
#   'request_slots': {'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'birmingham',
#    'date': 'tomorrow',
#    'moviename': 'deadpool',
#    'numberofpeople': '2',
#    'starttime': 'around 5pm',
#    'state': 'al',
#    'theater': 'carmike summit 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'The big short',
#    'numberofpeople': '2',
#    'starttime': '8:45 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'moviename': 'zootopia',
#    'numberofpeople': '4',
#    'starttime': 'matinee'},
#   'request_slots': {'date': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'la',
#    'date': 'tomorrow',
#    'distanceconstraints': 'downtown',
#    'moviename': 'creed',
#    'numberofpeople': '2',
#    'starttime': '7pm',
#    'video_format': '3d'},
#   'request_slots': {'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'birmingham',
#    'moviename': 'zootopia',
#    'numberofpeople': '2',
#    'state': 'al'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'spotlight',
#    'numberofpeople': '2',
#    'starttime': '9:00 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'moviename': 'avengers', 'numberofpeople': '5'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'spotlight',
#    'numberofpeople': '2',
#    'starttime': '9:00 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'hail caesar',
#    'numberofpeople': '2',
#    'starttime': '8:45 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'birmingham',
#    'date': 'today',
#    'moviename': 'zootopia',
#    'numberofpeople': '2',
#    'starttime': '2pm',
#    'state': 'al',
#    'theater': 'carmike 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'du quoin',
#    'moviename': 'star wars',
#    'numberofpeople': '2',
#    'state': 'illinois'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'hail caesar',
#    'numberofpeople': '2',
#    'starttime': '8:45 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'portland',
#    'moviename': 'star wars',
#    'numberofpeople': '2',
#    'state': 'oregon'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'los angeles',
#    'moviename': 'deadpool',
#    'numberofpeople': '1'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'regency academy 6 theater',
#    'date': 'tomorrow',
#    'moviename': 'creed',
#    'numberofpeople': 'four',
#    'starttime': 'around noon'},
#   'request_slots': {'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'spotlight',
#    'numberofpeople': '2',
#    'starttime': '9:00 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'date': 'tomorrow night',
#    'moviename': 'deadpool',
#    'numberofpeople': '1'},
#   'request_slots': {'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'portland',
#    'moviename': 'star wars',
#    'numberofpeople': '4',
#    'state': 'oregon'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'moviename': 'star wars',
#    'numberofpeople': '2',
#    'theater': 'shelby township'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'philadelphia',
#    'date': 'tomorrow',
#    'moviename': 'deadpool',
#    'numberofpeople': '4',
#    'zip': '19101'},
#   'request_slots': {'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'zootopia',
#    'numberofpeople': '2',
#    'starttime': '9:10 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'deadpool',
#    'numberofpeople': '2',
#    'starttime': '9:00 pm',
#    'theater': 'amc pacific place 11 theater'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'knoxville',
#    'date': 'tomorrow',
#    'distanceconstraints': 'downtown',
#    'moviename': 'the witch',
#    'numberofpeople': '2',
#    'starttime': 'evening around 7',
#    'state': 'tn',
#    'video_format': '3d'},
#   'request_slots': {'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'race',
#    'numberofpeople': '2',
#    'starttime': '10:00 pm',
#    'theater': 'amc pacific place 11 theater'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'zootopia',
#    'numberofpeople': '2',
#    'starttime': '9:10 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'birmingham',
#    'date': 'sunday',
#    'moviename': 'deadpool',
#    'numberofpeople': '2',
#    'starttime': 'around 2pm',
#    'state': 'al',
#    'theater': 'carmike summit 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'moviename': 'brothers grimsby', 'numberofpeople': '4'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'big short',
#    'numberofpeople': '2',
#    'starttime': '8:45 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'moviename': 'zootopia', 'numberofpeople': '5'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'the witch',
#    'numberofpeople': '2',
#    'starttime': '9:30 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'zootopia',
#    'numberofpeople': '2',
#    'starttime': '9:10 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'moviename': '10 cloverfield lane',
#    'numberofpeople': '3',
#    'theater': 'beaver creek stadium 12'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'spotlight',
#    'numberofpeople': '2',
#    'starttime': '9:00 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'race',
#    'numberofpeople': '2',
#    'starttime': '4:50 pm',
#    'theater': 'amc lowes oak tree 6'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'race',
#    'numberofpeople': '2',
#    'starttime': '10:00 pm',
#    'theater': 'amc pacific place 11 theater'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'the witch',
#    'numberofpeople': '2',
#    'starttime': '9:30 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'the witch',
#    'numberofpeople': '2',
#    'starttime': '9:30 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'birmingham',
#    'date': 'tomorrow',
#    'moviename': 'deadpool',
#    'numberofpeople': '1',
#    'starttime': '2pm',
#    'state': 'al',
#    'theater': 'carmike summit 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'moviename': 'deadpool',
#    'numberofpeople': '2'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'birmingham',
#    'date': 'thursday',
#    'moviename': 'deadpool',
#    'numberofpeople': '2',
#    'starttime': 'around 2pm',
#    'state': 'al',
#    'theater': 'carmike summit 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'moviename': 'eddie the eagle',
#    'numberofpeople': '4',
#    'zip': '94952'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'moviename': 'london has fallen',
#    'numberofpeople': 'two',
#    'zip': '90602'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'moviename': 'zootopia',
#    'numberofpeople': '4',
#    'state': 'california'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'zoolander 2',
#    'numberofpeople': '2',
#    'starttime': '9:25 pm',
#    'theater': 'regal meridian 16'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'las vegas',
#    'moviename': 'the other side of the door',
#    'numberofpeople': 'two',
#    'theater': 'southpoint casino'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'du Quoin',
#    'moviename': 'star wars',
#    'numberofpeople': '2',
#    'state': 'illinois'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'moviename': 'gods egypt', 'numberofpeople': '3'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'hail caesar',
#    'numberofpeople': '2',
#    'starttime': '8:45 pm',
#    'theater': 'regal meridian 16 theater'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'zootopia',
#    'numberofpeople': 'one',
#    'starttime': 'night'},
#   'request_slots': {'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'race',
#    'numberofpeople': '2',
#    'starttime': '10:00 pm',
#    'theater': 'amc pacific place 11 theater'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'race',
#    'numberofpeople': '2',
#    'starttime': '10:00 pm',
#    'theater': 'amc pacific place 11 theater'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'hail caesar',
#    'numberofpeople': '2',
#    'starttime': '7:15 pm',
#    'theater': 'amc lowes oak tree 6'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'triple 9',
#    'numberofpeople': '6',
#    'starttime': '7:10 pm',
#    'theater': 'amc lowes oak tree'},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'moviename': 'zootopia', 'numberofpeople': 'two'},
#   'request_slots': {'date': 'UNK', 'starttime': 'UNK', 'theater': 'UNK'}},
#  {'diaact': 'request',
#   'inform_slots': {'city': 'seattle',
#    'date': 'tomorrow',
#    'moviename': 'deadpool',
#    'numberofpeople': '2',
#    'starttime': '9:00 pm',
#    'theater': 'amc pacific place 11 theater'},
#   'request_slots': {}}]

# %%
if USE_USERSIM:
    user = UserSimulator(user_goals, constants, database)
else:
    user = User(constants)
emc = ErrorModelController(db_dict, constants)
state_tracker = StateTracker(database, constants)
dqn_agent = DQNAgent(state_tracker.get_state_size(), constants)

# %%
warmup_run()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Warmup Started...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# ...Warmup Ended

# %%
train_run()
# Out:
# Streaming output truncated to the last 5000 lines.
# success :False
# period_success_total 32
# Current episode: 38341
# success :False
# period_success_total 32
# Current episode: 38342
# success :True
# period_success_total 33
# Current episode: 38343
# success :True
# period_success_total 34
# Current episode: 38344
# success :True
# period_success_total 35
# Current episode: 38345
# success :True
# period_success_total 36
# Current episode: 38346
# success :False
# period_success_total 36
# Current episode: 38347
# success :True
# period_success_total 37
# Current episode: 38348
# success :True
# period_success_total 38
# Current episode: 38349
# success :True
# period_success_total 39
# Current episode: 38350
# success :True
# period_success_total 40
# Current episode: 38351
# success :False
# period_success_total 40
# Current episode: 38352
# success :True
# period_success_total 41
# Current episode: 38353
# success :True
# period_success_total 42
# Current episode: 38354
# success :False
# period_success_total 42
# Current episode: 38355
# success :True
# period_success_total 43
# Current episode: 38356
# success :True
# period_success_total 44
# Current episode: 38357
# success :True
# period_success_total 45
# Current episode: 38358
# success :True
# period_success_total 46
# Current episode: 38359
# success :True
# period_success_total 47
# Current episode: 38360
# success :True
# period_success_total 48
# Current episode: 38361
# success :True
# period_success_total 49
# Current episode: 38362
# success :False
# period_success_total 49
# Current episode: 38363
# success :True
# period_success_total 50
# Current episode: 38364
# success :True
# period_success_total 51
# Current episode: 38365
# success :True
# period_success_total 52
# Current episode: 38366
# success :True
# period_success_total 53
# Current episode: 38367
# success :True
# period_success_total 54
# Current episode: 38368
# success :False
# period_success_total 54
# Current episode: 38369
# success :True
# period_success_total 55
# Current episode: 38370
# success :False
# period_success_total 55
# Current episode: 38371
# success :True
# period_success_total 56
# Current episode: 38372
# success :True
# period_success_total 57
# Current episode: 38373
# success :True
# period_success_total 58
# Current episode: 38374
# success :False
# period_success_total 58
# Current episode: 38375
# success :True
# period_success_total 59
# Current episode: 38376
# success :True
# period_success_total 60
# Current episode: 38377
# success :True
# period_success_total 61
# Current episode: 38378
# success :True
# period_success_total 62
# Current episode: 38379
# success :True
# period_success_total 63
# period_success_total 68
# Current episode: 39877
# success :True
# period_success_total 69
# Current episode: 39878
# success :True
# period_success_total 70
# Current episode: 39879
# success :False
# period_success_total 70
# Current episode: 39880
# success :True
# period_success_total 71
# Current episode: 39881
# success :True
# period_success_total 72
# Current episode: 39882
# success :True
# period_success_total 73
# Current episode: 39883
# success :False
# period_success_total 73
# Current episode: 39884
# success :True
# period_success_total 74
# Current episode: 39885
# success :True
# period_success_total 75
# Current episode: 39886
# success :True
# period_success_total 76
# Current episode: 39887
# success :True
# period_success_total 77
# Current episode: 39888
# success :False
# period_success_total 77
# Current episode: 39889
# success :False
# period_success_total 77
# Current episode: 39890
# success :True
# period_success_total 78
# Current episode: 39891
# success :True
# period_success_total 79
# Current episode: 39892
# success :True
# period_success_total 80
# Current episode: 39893
# success :True
# period_success_total 81
# Current episode: 39894
# success :True
# period_success_total 82
# Current episode: 39895
# success :True
# period_success_total 83
# Current episode: 39896
# success :True
# period_success_total 84
# Current episode: 39897
# success :True
# period_success_total 85
# Current episode: 39898
# success :True
# period_success_total 86
# Current episode: 39899
# success :False
# period_success_total 86
# Current episode: 39900
# success :False
# period_success_total 86
# episode 39900: success rate: 0.86
# Current episode: 39901
# success :True
# period_success_total 1
# Current episode: 39902
# success :True
# period_success_total 2
# Current episode: 39903
# success :True
# period_success_total 3
# Current episode: 39904
# success :True
# period_success_total 4
# Current episode: 39905
# success :True
# period_success_total 5
# Current episode: 39906
# success :True
# period_success_total 6
# Current episode: 39907
# success :True
# period_success_total 7
# Current episode: 39908
# success :True
# period_success_total 8
# Current episode: 39909
# success :True
# period_success_total 9
# Current episode: 39910
# success :True
# period_success_total 10
# Current episode: 39911
# success :True
# period_success_total 11
# Current episode: 39912
# success :True
# period_success_total 12
# Current episode: 39913
# success :True
# period_success_total 13
# Current episode: 39914
# success :False
# period_success_total 13
# Current episode: 39915
# success :True
# period_success_total 14
# Current episode: 39916
# success :False
# period_success_total 14
# Current episode: 39917
# success :True
# period_success_total 15
# Current episode: 39918
# success :True
# period_success_total 16
# Current episode: 39919
# success :True
# period_success_total 17
# Current episode: 39920
# success :False
# period_success_total 17
# Current episode: 39921
# success :True
# period_success_total 18
# Current episode: 39922
# success :True
# period_success_total 19
# Current episode: 39923
# success :True
# period_success_total 20
# Current episode: 39924
# success :True
# period_success_total 21
# Current episode: 39925
# success :True
# period_success_total 22
# Current episode: 39926
# success :True
# period_success_total 23
# Current episode: 39927
# success :True
# period_success_total 24
# Current episode: 39928
# success :False
# period_success_total 24
# Current episode: 39929
# success :True
# period_success_total 25
# Current episode: 39930
# success :True
# period_success_total 26
# Current episode: 39931
# success :True
# period_success_total 27
# Current episode: 39932
# success :True
# period_success_total 28
# Current episode: 39933
# success :True
# period_success_total 29
# Current episode: 39934
# success :True
# period_success_total 30
# Current episode: 39935
# success :False
# period_success_total 30
# Current episode: 39936
# success :True
# period_success_total 31
# Current episode: 39937
# success :False
# period_success_total 31
# Current episode: 39938
# success :True
# period_success_total 32
