# %%
# import json
import pymongo
import pandas as pd
import pickle
client = pymongo.MongoClient("mongodb://taindp:chatbot2020@thesis-shard-00-00.bdisf.mongodb.net:27017,thesis-shard-00-01.bdisf.mongodb.net:27017,thesis-shard-00-02.bdisf.mongodb.net:27017/hcmut?ssl=true&replicaSet=atlas-12fynb-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.hcmut
collection = db['general']

# %%
result_query = collection.find({})
list_query = []
for item in result_query:
    list_query.append(item)
df_query = pd.DataFrame(list_query)
# df_query['case'] = [['thi tốt nghiệp trung học phổ thông'] for _ in range(len(df_query))]

# %%
# del df_query['satisfy']

# %%
df_query.head(1)
# Out:
#                         _id major_code          major_name  \
# 0  60484802f66da7ba0324ce1f      [114]  [kỹ thuật hóa học]
#
#                       type_edu    point    year  \
# 0  [đại học chính quy đại trà]  [26.75]  [2020]
#
#                                               career  \
# 0  [quản lý vận hành và vận hành các hệ thống thi...
#
#                       subject                 tuition subject_group  \
# 0  [toán, hóa học, tiếng anh]  [320000 việt nam đồng]     [d07, d7]
#
#                                    case criteria  \
# 0  [thi tốt nghiệp trung học phổ thông]    [320]
#
#                                               object
# 0  [tất cả các thí sinh có kết quả thi tốt nghiệp...

# %% [markdown]
# # Remove 2019

# %%
# dict_query = df_query.to_dict('records')
# list_rm_2019 = []
# for item in dict_query:
#     if item['year'][0] != '2019':
#         list_rm_2019.append(item)

# %%
# df_query = pd.DataFrame(list_rm_2019)

# %%
# df_query

# %%
# dict_final = df_query.to_dict('records')
# file_out = open('/home/taindp/PycharmProjects/thesis/data/database_full_feature.json','w')
# for item in dict_final:
#     item_str = str(item).replace(r"'",r'"')
#     file_out.write(item_str)
#     file_out.write('\n')

# %% [markdown]
# # Load new feature

# %%
cp_priority = list_rm_2019.copy()

# %%
# list_rm_2019

# %% [markdown]
# ## priority

# %%
new_feature = pd.read_csv('/home/taindp/PycharmProjects/thesis/data/add_feature_feb9.csv')
new_feature['major_code'] = [str(item) for item in list(new_feature['major_code'])]
new_feature['criteria'] = [str(item) for item in list(new_feature['criteria'])]
new_feature['priority_case'] = [str(item) for item in list(new_feature['priority_case'])]
new_feature['capacity_case'] = [str(item) for item in list(new_feature['capacity_case'])]

# %%
# new_feature

# %%
df_priority = pd.DataFrame(cp_priority)

# %%
list_priority_point = []
list_priority_case = []
list_priority_rm_subject_group = []
list_priority_rm_subject = []
for item in cp_priority:
    major_code = item['major_code'][0]
    type_edu = item['type_edu'][0]
#     print(type_edu)
    df_iloc = new_feature[(new_feature['major_code']==major_code) & (new_feature['type_edu']==type_edu)]
    priority_point = [df_iloc['priority_case'].iloc[0]]
    list_priority_case.append(['ưu tiên xét tuyển'])
    list_priority_rm_subject_group.append([])
    list_priority_rm_subject.append([])
    list_priority_point.append(priority_point)

# %%
df_priority['point'] = list_priority_point
df_priority['case'] = list_priority_case
df_priority['subject'] = list_priority_rm_subject
df_priority['subject_group'] = list_priority_rm_subject_group
df_priority.head(1)
# Out:
#                         _id major_code      major_name  \
# 0  60308e0a4226a6c7e6b7d026      [112]  [kỹ thuật dệt]
#
#                       type_edu   point    year  \
# 0  [đại học chính quy đại trà]  [78.8]  [2020]
#
#                                               career subject  \
# 0  [quản lý vận hành các dây chuyền sản xuất sợi ...      []
#
#                   tuition subject_group                 case criteria  \
# 0  [320000 việt nam đồng]            []  [ưu tiên xét tuyển]     [90]
#
#                                               object  \
# 0  [tất cả các thí sinh có kết quả thi tốt nghiệp...
#
#                                             register  \
# 0  [các thí sinh đăng ký dự thi kỳ thi tốt nghiệp...
#
#                                            admission  \
# 0  [là tổng điểm 3 bài thi môn thi của tổ hợp môn...
#
#                                       time
# 0  [theo kế hoạch tuyển sinh của bộ gd đt]

# %% [markdown]
# # capacity

# %%
cp_capacity = list_rm_2019.copy()
df_capacity = pd.DataFrame(cp_capacity)

# %%
list_capacity_point = []
list_capacity_case = []
list_capacity_rm_subject_group = []
list_capacity_rm_subject = []
for item in cp_capacity:
    major_code = item['major_code'][0]
    type_edu = item['type_edu'][0]
#     print(type_edu)
    df_iloc = new_feature[(new_feature['major_code']==major_code) & (new_feature['type_edu']==type_edu)]
    capacity_point = [df_iloc['capacity_case'].iloc[0]]
    list_capacity_case.append(['đánh giá năng lực'])
    list_capacity_rm_subject_group.append([])
    list_capacity_rm_subject.append([])
    list_capacity_point.append(capacity_point)

# %%
df_capacity['point'] = list_capacity_point
df_capacity['case'] = list_capacity_case
df_capacity['subject'] = list_capacity_rm_subject
df_capacity['subject_group'] = list_capacity_rm_subject_group
df_capacity.head(1)
# Out:
#                         _id major_code      major_name  \
# 0  60308e0a4226a6c7e6b7d026      [112]  [kỹ thuật dệt]
#
#                       type_edu  point    year  \
# 0  [đại học chính quy đại trà]  [702]  [2020]
#
#                                               career subject  \
# 0  [quản lý vận hành các dây chuyền sản xuất sợi ...      []
#
#                   tuition subject_group                 case criteria  \
# 0  [320000 việt nam đồng]            []  [đánh giá năng lực]     [90]
#
#                                               object  \
# 0  [tất cả các thí sinh có kết quả thi tốt nghiệp...
#
#                                             register  \
# 0  [các thí sinh đăng ký dự thi kỳ thi tốt nghiệp...
#
#                                            admission  \
# 0  [là tổng điểm 3 bài thi môn thi của tổ hợp môn...
#
#                                       time
# 0  [theo kế hoạch tuyển sinh của bộ gd đt]

# %% [markdown]
# # Concat

# %%
df_concat = pd.concat([df_query,df_priority,df_capacity],axis=0)
df_concat
# Out:
#                           _id major_code                       major_name  \
# 0    60308e0a4226a6c7e6b7d026      [112]                   [kỹ thuật dệt]
# 1    60308e0a4226a6c7e6b7d027      [108]                  [kỹ thuật điện]
# 2    60308e0a4226a6c7e6b7d028      [114]               [kỹ thuật hóa học]
# 3    60308e0a4226a6c7e6b7d029      [125]            [kỹ thuật môi trường]
# 4    60308e0a4226a6c7e6b7d02a      [441]          [bảo dưỡng công nghiệp]
# ..                        ...        ...                              ...
# 321  60308e0a4226a6c7e6b7d169      [215]   [kỹ thuật công trình xây dựng]
# 322  60308e0a4226a6c7e6b7d16a      [225]  [quản lý tài nguyên môi trường]
# 323  60308e0a4226a6c7e6b7d16b      [142]        [công nghệ kỹ thuật ô tô]
# 324  60308e0a4226a6c7e6b7d16c      [220]               [kỹ thuật dầu khí]
# 325  60308e0a4226a6c7e6b7d16d      [110]            [kỹ thuật cơ điện tử]
#
#                                     type_edu    point    year  \
# 0                [đại học chính quy đại trà]   [23.5]  [2020]
# 1                [đại học chính quy đại trà]  [26.75]  [2020]
# 2                [đại học chính quy đại trà]  [26.75]  [2020]
# 3                [đại học chính quy đại trà]  [24.25]  [2020]
# 4                        [phân hiệu bến tre]   [20.5]  [2020]
# ..                                       ...      ...     ...
# 321  [chương trình chất lượng cao tiên tiến]    [703]  [2020]
# 322  [chương trình chất lượng cao tiên tiến]    [736]  [2020]
# 323              [đại học chính quy đại trà]    [837]  [2020]
# 324  [chương trình chất lượng cao tiên tiến]    [727]  [2020]
# 325              [đại học chính quy đại trà]    [849]  [2020]
#
#                                                 career  \
# 0    [quản lý vận hành các dây chuyền sản xuất sợi ...
# 1    [thiết kế thiết bị điện và điện tử công suất, ...
# 2    [quản lý vận hành và vận hành các hệ thống thi...
# 3    [tư vấn thiết kế và thi công xây dựng công trì...
# 4    [tổ chức quản lý bảo dưỡng, tổ chức quản lý kh...
# ..                                                 ...
# 321  [thiết kế, thi công, quản lý thi công, thẩm tr...
# 322  [quản lý dự án các doanh nghiệp sản xuất các k...
# 323  [tư vấn và chuyển giao công nghệ lĩnh vực ô tô...
# 324  [khoan khai thác tại hiện trường, đo vẽ bản đồ...
# 325  [quản lý điều hành giải pháp tự động hóa sử dụ...
#
#                         subject                  tuition subject_group  \
# 0     [toán, vật lý, tiếng anh]   [320000 việt nam đồng]     [a01, a1]
# 1       [toán, vật lý, hóa học]   [320000 việt nam đồng]      [a00, a]
# 2    [toán, hóa học, tiếng anh]   [320000 việt nam đồng]     [d07, d7]
# 3       [toán, vật lý, hóa học]   [320000 việt nam đồng]      [a00, a]
# 4       [toán, vật lý, hóa học]   [320000 việt nam đồng]      [a00, a]
# ..                          ...                      ...           ...
# 321                          []  [1850000 việt nam đồng]            []
# 322                          []  [1850000 việt nam đồng]            []
# 323                          []   [320000 việt nam đồng]            []
# 324                          []  [1850000 việt nam đồng]            []
# 325                          []   [320000 việt nam đồng]            []
#
#                                      case criteria  \
# 0    [thi tốt nghiệp trung học phổ thông]     [90]
# 1    [thi tốt nghiệp trung học phổ thông]    [670]
# 2    [thi tốt nghiệp trung học phổ thông]    [320]
# 3    [thi tốt nghiệp trung học phổ thông]    [120]
# 4    [thi tốt nghiệp trung học phổ thông]      [0]
# ..                                    ...      ...
# 321                   [đánh giá năng lực]     [80]
# 322                   [đánh giá năng lực]     [60]
# 323                   [đánh giá năng lực]     [90]
# 324                   [đánh giá năng lực]     [50]
# 325                   [đánh giá năng lực]    [105]
#
#                                                 object  \
# 0    [tất cả các thí sinh có kết quả thi tốt nghiệp...
# 1    [tất cả các thí sinh có kết quả thi tốt nghiệp...
# 2    [tất cả các thí sinh có kết quả thi tốt nghiệp...
# 3    [tất cả các thí sinh có kết quả thi tốt nghiệp...
# 4    [tất cả các thí sinh có kết quả thi tốt nghiệp...
# ..                                                 ...
# 321  [tất cả các thí sinh có kết quả kỳ đánh giá nă...
# 322  [tất cả các thí sinh có kết quả kỳ đánh giá nă...
# 323  [tất cả các thí sinh có kết quả kỳ đánh giá nă...
# 324  [tất cả các thí sinh có kết quả kỳ đánh giá nă...
# 325  [tất cả các thí sinh có kết quả kỳ đánh giá nă...
#
#                                               register  \
# 0    [các thí sinh đăng ký dự thi kỳ thi tốt nghiệp...
# 1    [các thí sinh đăng ký dự thi kỳ thi tốt nghiệp...
# 2    [các thí sinh đăng ký dự thi kỳ thi tốt nghiệp...
# 3    [các thí sinh đăng ký dự thi kỳ thi tốt nghiệp...
# 4    [các thí sinh đăng ký dự thi kỳ thi tốt nghiệp...
# ..                                                 ...
# 321  [các thí sinh đăng ký xét tuyển vào các nhóm n...
# 322  [các thí sinh đăng ký xét tuyển vào các nhóm n...
# 323  [các thí sinh đăng ký xét tuyển vào các nhóm n...
# 324  [các thí sinh đăng ký xét tuyển vào các nhóm n...
# 325  [các thí sinh đăng ký xét tuyển vào các nhóm n...
#
#                                              admission  \
# 0    [là tổng điểm 3 bài thi môn thi của tổ hợp môn...
# 1    [là tổng điểm 3 bài thi môn thi của tổ hợp môn...
# 2    [là tổng điểm 3 bài thi môn thi của tổ hợp môn...
# 3    [là tổng điểm 3 bài thi môn thi của tổ hợp môn...
# 4    [là tổng điểm 3 bài thi môn thi của tổ hợp môn...
# ..                                                 ...
# 321  [là điểm bài thi đánh giá năng lực điểm xét tu...
# 322  [là điểm bài thi đánh giá năng lực điểm xét tu...
# 323  [là điểm bài thi đánh giá năng lực điểm xét tu...
# 324  [là điểm bài thi đánh giá năng lực điểm xét tu...
# 325  [là điểm bài thi đánh giá năng lực điểm xét tu...
#
#                                                   time
# 0              [theo kế hoạch tuyển sinh của bộ gd đt]
# 1              [theo kế hoạch tuyển sinh của bộ gd đt]
# 2              [theo kế hoạch tuyển sinh của bộ gd đt]
# 3              [theo kế hoạch tuyển sinh của bộ gd đt]
# 4              [theo kế hoạch tuyển sinh của bộ gd đt]
# ..                                                 ...
# 321  [theo kế hoạch tuyển sinh của đhqg hcm từ thán...
# 322  [theo kế hoạch tuyển sinh của đhqg hcm từ thán...
# 323  [theo kế hoạch tuyển sinh của đhqg hcm từ thán...
# 324  [theo kế hoạch tuyển sinh của đhqg hcm từ thán...
# 325  [theo kế hoạch tuyển sinh của đhqg hcm từ thán...
#
# [978 rows x 16 columns]

# %%
del df_concat['_id']

# %%
list_criteria = []
dict_concat = df_concat.to_dict('records')
for item in dict_concat:
    major_code = item['major_code'][0]
    type_edu = item['type_edu'][0]
    df_iloc = new_feature[(new_feature['major_code']==major_code) & (new_feature['type_edu']==type_edu)]
    criteria = [df_iloc['criteria'].iloc[0]]
    list_criteria.append(criteria)
df_concat['criteria'] = list_criteria

# %%
df_concat
# Out:
#     major_code                       major_name  \
# 0        [112]                   [kỹ thuật dệt]
# 1        [108]                  [kỹ thuật điện]
# 2        [114]               [kỹ thuật hóa học]
# 3        [125]            [kỹ thuật môi trường]
# 4        [441]          [bảo dưỡng công nghiệp]
# ..         ...                              ...
# 321      [215]   [kỹ thuật công trình xây dựng]
# 322      [225]  [quản lý tài nguyên môi trường]
# 323      [142]        [công nghệ kỹ thuật ô tô]
# 324      [220]               [kỹ thuật dầu khí]
# 325      [110]            [kỹ thuật cơ điện tử]
#
#                                     type_edu    point    year  \
# 0                [đại học chính quy đại trà]   [23.5]  [2020]
# 1                [đại học chính quy đại trà]  [26.75]  [2020]
# 2                [đại học chính quy đại trà]  [26.75]  [2020]
# 3                [đại học chính quy đại trà]  [24.25]  [2020]
# 4                        [phân hiệu bến tre]   [20.5]  [2020]
# ..                                       ...      ...     ...
# 321  [chương trình chất lượng cao tiên tiến]    [703]  [2020]
# 322  [chương trình chất lượng cao tiên tiến]    [736]  [2020]
# 323              [đại học chính quy đại trà]    [837]  [2020]
# 324  [chương trình chất lượng cao tiên tiến]    [727]  [2020]
# 325              [đại học chính quy đại trà]    [849]  [2020]
#
#                                                 career  \
# 0    [quản lý vận hành các dây chuyền sản xuất sợi ...
# 1    [thiết kế thiết bị điện và điện tử công suất, ...
# 2    [quản lý vận hành và vận hành các hệ thống thi...
# 3    [tư vấn thiết kế và thi công xây dựng công trì...
# 4    [tổ chức quản lý bảo dưỡng, tổ chức quản lý kh...
# ..                                                 ...
# 321  [thiết kế, thi công, quản lý thi công, thẩm tr...
# 322  [quản lý dự án các doanh nghiệp sản xuất các k...
# 323  [tư vấn và chuyển giao công nghệ lĩnh vực ô tô...
# 324  [khoan khai thác tại hiện trường, đo vẽ bản đồ...
# 325  [quản lý điều hành giải pháp tự động hóa sử dụ...
#
#                         subject                  tuition subject_group  \
# 0     [toán, vật lý, tiếng anh]   [320000 việt nam đồng]     [a01, a1]
# 1       [toán, vật lý, hóa học]   [320000 việt nam đồng]      [a00, a]
# 2    [toán, hóa học, tiếng anh]   [320000 việt nam đồng]     [d07, d7]
# 3       [toán, vật lý, hóa học]   [320000 việt nam đồng]      [a00, a]
# 4       [toán, vật lý, hóa học]   [320000 việt nam đồng]      [a00, a]
# ..                          ...                      ...           ...
# 321                          []  [1850000 việt nam đồng]            []
# 322                          []  [1850000 việt nam đồng]            []
# 323                          []   [320000 việt nam đồng]            []
# 324                          []  [1850000 việt nam đồng]            []
# 325                          []   [320000 việt nam đồng]            []
#
#                                      case criteria  \
# 0    [thi tốt nghiệp trung học phổ thông]     [90]
# 1    [thi tốt nghiệp trung học phổ thông]    [670]
# 2    [thi tốt nghiệp trung học phổ thông]    [320]
# 3    [thi tốt nghiệp trung học phổ thông]    [120]
# 4    [thi tốt nghiệp trung học phổ thông]      [0]
# ..                                    ...      ...
# 321                   [đánh giá năng lực]     [80]
# 322                   [đánh giá năng lực]     [60]
# 323                   [đánh giá năng lực]     [90]
# 324                   [đánh giá năng lực]     [50]
# 325                   [đánh giá năng lực]    [105]
#
#                                                 object  \
# 0    [tất cả các thí sinh có kết quả thi tốt nghiệp...
# 1    [tất cả các thí sinh có kết quả thi tốt nghiệp...
# 2    [tất cả các thí sinh có kết quả thi tốt nghiệp...
# 3    [tất cả các thí sinh có kết quả thi tốt nghiệp...
# 4    [tất cả các thí sinh có kết quả thi tốt nghiệp...
# ..                                                 ...
# 321  [tất cả các thí sinh có kết quả kỳ đánh giá nă...
# 322  [tất cả các thí sinh có kết quả kỳ đánh giá nă...
# 323  [tất cả các thí sinh có kết quả kỳ đánh giá nă...
# 324  [tất cả các thí sinh có kết quả kỳ đánh giá nă...
# 325  [tất cả các thí sinh có kết quả kỳ đánh giá nă...
#
#                                               register  \
# 0    [các thí sinh đăng ký dự thi kỳ thi tốt nghiệp...
# 1    [các thí sinh đăng ký dự thi kỳ thi tốt nghiệp...
# 2    [các thí sinh đăng ký dự thi kỳ thi tốt nghiệp...
# 3    [các thí sinh đăng ký dự thi kỳ thi tốt nghiệp...
# 4    [các thí sinh đăng ký dự thi kỳ thi tốt nghiệp...
# ..                                                 ...
# 321  [các thí sinh đăng ký xét tuyển vào các nhóm n...
# 322  [các thí sinh đăng ký xét tuyển vào các nhóm n...
# 323  [các thí sinh đăng ký xét tuyển vào các nhóm n...
# 324  [các thí sinh đăng ký xét tuyển vào các nhóm n...
# 325  [các thí sinh đăng ký xét tuyển vào các nhóm n...
#
#                                              admission  \
# 0    [là tổng điểm 3 bài thi môn thi của tổ hợp môn...
# 1    [là tổng điểm 3 bài thi môn thi của tổ hợp môn...
# 2    [là tổng điểm 3 bài thi môn thi của tổ hợp môn...
# 3    [là tổng điểm 3 bài thi môn thi của tổ hợp môn...
# 4    [là tổng điểm 3 bài thi môn thi của tổ hợp môn...
# ..                                                 ...
# 321  [là điểm bài thi đánh giá năng lực điểm xét tu...
# 322  [là điểm bài thi đánh giá năng lực điểm xét tu...
# 323  [là điểm bài thi đánh giá năng lực điểm xét tu...
# 324  [là điểm bài thi đánh giá năng lực điểm xét tu...
# 325  [là điểm bài thi đánh giá năng lực điểm xét tu...
#
#                                                   time
# 0              [theo kế hoạch tuyển sinh của bộ gd đt]
# 1              [theo kế hoạch tuyển sinh của bộ gd đt]
# 2              [theo kế hoạch tuyển sinh của bộ gd đt]
# 3              [theo kế hoạch tuyển sinh của bộ gd đt]
# 4              [theo kế hoạch tuyển sinh của bộ gd đt]
# ..                                                 ...
# 321  [theo kế hoạch tuyển sinh của đhqg hcm từ thán...
# 322  [theo kế hoạch tuyển sinh của đhqg hcm từ thán...
# 323  [theo kế hoạch tuyển sinh của đhqg hcm từ thán...
# 324  [theo kế hoạch tuyển sinh của đhqg hcm từ thán...
# 325  [theo kế hoạch tuyển sinh của đhqg hcm từ thán...
#
# [978 rows x 15 columns]

# %%
list_case_clean = pickle.load(open('/home/taindp/PycharmProjects/thesis/data/list_case_clean.pkl','rb'))
list_case_clean
# Out:
# {'formal': {'object': ['tất cả các thí sinh có kết quả thi tốt nghiệp thpt 2021'],
#   'register': ['đăng ký dự thi kỳ thi tốt nghiệp thpt 2021',
#    'đăng ký xét tuyển']},
#  'priority': {'object': ['học sinh giỏi thuộc các trường thpt chuyên năng khiếu',
#    'tốt nghiệp thpt năm 2021',
#    'học sinh giỏi từ 2 năm trở lên đối với học sinh các trường thpt chuyên năng khiếu thực hành sư phạm',
#    'học sinh giỏi 3 năm đối với các trường thpt còn lại trong danh sách',
#    'thành viên đội tuyển của trường hoặc tỉnh thành tham dự kỳ thi học sinh giỏi quốc gia',
#    'có hạnh kiểm tốt trong năm lớp 10 lớp 11 và lớp 12',
#    'chỉ áp dụng một lần đúng năm học sinh tốt nghiệp thpt'],
#   'register': ['đăng ký ưu tiên xét tuyển',
#    'tối đa 03 nguyện vọng',
#    'có phân biệt số thứ tự nguyện vọng']},
#  'capacity': {'object': ['tất cả các thí sinh có kết quả kỳ đánh giá năng lực do đại học quốc gia tp hcm tổ chức'],
#   'register': ['đăng ký ưu tiên xét tuyển',
#    'tối đa 03 nguyện vọng',
#    'có phân biệt số thứ tự nguyện vọng']}}

# %%
dict_concat = df_concat.to_dict('records')

list_object = []
list_register = []
list_admission = []
list_time = []

for item in dict_concat:
    case = item['case'][0]
    if case == 'thi tốt nghiệp trung học phổ thông':
        list_object.append(list_case_clean['formal']['object'])
        list_register.append(list_case_clean['formal']['register'])
#         list_admission.append(list_case_clean['formal']['admission'])
#         list_time.append(list_case_clean['formal']['time'])
    elif case == 'ưu tiên xét tuyển':
        list_object.append(list_case_clean['priority']['object'])
        list_register.append(list_case_clean['priority']['register'])
#         list_admission.append(list_case_clean['priority']['admission'])
#         list_time.append(list_case_clean['priority']['time'])
    elif case == 'đánh giá năng lực':
        list_object.append(list_case_clean['capacity']['object'])
        list_register.append(list_case_clean['capacity']['register'])
#         list_admission.append(list_case_clean['capacity']['admission'])
#         list_time.append(list_case_clean['capacity']['time'])

# %%
df_concat['object'] = list_object
df_concat['register'] = list_register
# df_concat['admission'] = list_admission
# df_concat['time'] = list_time

# %%
df_concat.head()
# Out:
#   major_code               major_name                     type_edu    point  \
# 0      [112]           [kỹ thuật dệt]  [đại học chính quy đại trà]   [23.5]
# 1      [108]          [kỹ thuật điện]  [đại học chính quy đại trà]  [26.75]
# 2      [114]       [kỹ thuật hóa học]  [đại học chính quy đại trà]  [26.75]
# 3      [125]    [kỹ thuật môi trường]  [đại học chính quy đại trà]  [24.25]
# 4      [441]  [bảo dưỡng công nghiệp]          [phân hiệu bến tre]   [20.5]
#
#      year                                             career  \
# 0  [2020]  [quản lý vận hành các dây chuyền sản xuất sợi ...
# 1  [2020]  [thiết kế thiết bị điện và điện tử công suất, ...
# 2  [2020]  [quản lý vận hành và vận hành các hệ thống thi...
# 3  [2020]  [tư vấn thiết kế và thi công xây dựng công trì...
# 4  [2020]  [tổ chức quản lý bảo dưỡng, tổ chức quản lý kh...
#
#                       subject                 tuition subject_group  \
# 0   [toán, vật lý, tiếng anh]  [320000 việt nam đồng]     [a01, a1]
# 1     [toán, vật lý, hóa học]  [320000 việt nam đồng]      [a00, a]
# 2  [toán, hóa học, tiếng anh]  [320000 việt nam đồng]     [d07, d7]
# 3     [toán, vật lý, hóa học]  [320000 việt nam đồng]      [a00, a]
# 4     [toán, vật lý, hóa học]  [320000 việt nam đồng]      [a00, a]
#
#                                    case criteria  \
# 0  [thi tốt nghiệp trung học phổ thông]     [90]
# 1  [thi tốt nghiệp trung học phổ thông]    [670]
# 2  [thi tốt nghiệp trung học phổ thông]    [320]
# 3  [thi tốt nghiệp trung học phổ thông]    [120]
# 4  [thi tốt nghiệp trung học phổ thông]      [0]
#
#                                               object  \
# 0  [tất cả các thí sinh có kết quả thi tốt nghiệp...
# 1  [tất cả các thí sinh có kết quả thi tốt nghiệp...
# 2  [tất cả các thí sinh có kết quả thi tốt nghiệp...
# 3  [tất cả các thí sinh có kết quả thi tốt nghiệp...
# 4  [tất cả các thí sinh có kết quả thi tốt nghiệp...
#
#                                             register  \
# 0  [đăng ký dự thi kỳ thi tốt nghiệp thpt 2021, đ...
# 1  [đăng ký dự thi kỳ thi tốt nghiệp thpt 2021, đ...
# 2  [đăng ký dự thi kỳ thi tốt nghiệp thpt 2021, đ...
# 3  [đăng ký dự thi kỳ thi tốt nghiệp thpt 2021, đ...
# 4  [đăng ký dự thi kỳ thi tốt nghiệp thpt 2021, đ...
#
#                                            admission  \
# 0  [là tổng điểm 3 bài thi môn thi của tổ hợp môn...
# 1  [là tổng điểm 3 bài thi môn thi của tổ hợp môn...
# 2  [là tổng điểm 3 bài thi môn thi của tổ hợp môn...
# 3  [là tổng điểm 3 bài thi môn thi của tổ hợp môn...
# 4  [là tổng điểm 3 bài thi môn thi của tổ hợp môn...
#
#                                       time
# 0  [theo kế hoạch tuyển sinh của bộ gd đt]
# 1  [theo kế hoạch tuyển sinh của bộ gd đt]
# 2  [theo kế hoạch tuyển sinh của bộ gd đt]
# 3  [theo kế hoạch tuyển sinh của bộ gd đt]
# 4  [theo kế hoạch tuyển sinh của bộ gd đt]

# %%
del df_concat['admission']
del df_concat['time']

# %%
dict_concat = df_concat.to_dict('records')
list_document_unique = []
for item in dict_concat:
    if item not in list_document_unique:
        list_document_unique.append(item)
len(list_document_unique)
# Out:
# 327

# %%
df_concat = pd.DataFrame(list_document_unique)
df_concat['case']
# Out:
# 0      [thi tốt nghiệp trung học phổ thông]
# 1      [thi tốt nghiệp trung học phổ thông]
# 2      [thi tốt nghiệp trung học phổ thông]
# 3      [thi tốt nghiệp trung học phổ thông]
# 4      [thi tốt nghiệp trung học phổ thông]
#                        ...
# 322                     [đánh giá năng lực]
# 323                     [đánh giá năng lực]
# 324                     [đánh giá năng lực]
# 325                     [đánh giá năng lực]
# 326                     [đánh giá năng lực]
# Name: case, Length: 327, dtype: object

# %%
# dict_final = df_concat.to_dict('records')
# file_out = open('/home/taindp/PycharmProjects/thesis/data/database_full_feature.json','w')
# for item in dict_final:
#     item_str = str(item).replace(r"'",r'"')
#     file_out.write(item_str)
#     file_out.write('\n')

# %%
# dict_final[-1]
