# %%
import json
import matplotlib.pyplot as plt

# %%
goal_ref = json.load(open('/home/taindp/Jupyter/custom_dqn/data/goal_ref.json','r'))

# %%
rq_slot = []
inf_slot = []
for item in goal_ref:
    print(len(list(item['inform_slots'].keys())))
#     inf_slot.append(len(list(item['inform_slots'].keys())))
# plt.hist(inf_slot,bins=10)
# Out:
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# ...

# %%
# những slot request trong goal là all slot
# những slot inform trong goal là all slot
# --> vẫn dùng goal 400
# rule_requests == agent_request_slots == AGENT_REQUEST_OBJECT

# %%
for i in range(1):
    print(i)

# %%
"""
AGENT_REQUEST_OBJECT = {
    "major_code": "mã ngành",
    "major_name": "tên ngành",
    "type_edu": "chương trình đào tạo",
    "point": "điểm chuẩn",
    "subject_group": "tổ hợp khối",
    "year":"năm",
}
"""

# %%
agent_request_slots = ['major_code','major_name','type_edu','point','subject_group','year']
